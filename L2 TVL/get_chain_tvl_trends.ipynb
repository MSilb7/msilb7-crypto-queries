# %%
import pandas as pd
import requests as r
import plotly.express as px
import plotly.graph_objects as go
from datetime import datetime, timedelta, date
import numpy as np
import time
import os
import asyncio, aiohttp, nest_asyncio
from aiohttp_retry import RetryClient, ExponentialRetry
import defillama_utils as dfl
nest_asyncio.apply()
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:71.0) Gecko/20100101 Firefox/71.0'}

# %%
# Out:
#              category                                             chains  \
# 0      Liquid Staking  [Ethereum, Solana, Moonbeam, Moonriver, Terra ...
# 1                 CDP                                         [Ethereum]
# 2               Dexes  [Ethereum, Arbitrum, Polygon, Optimism, Fantom...
# 3             Lending                     [Ethereum, Polygon, Avalanche]
# 4              Bridge                                         [Ethereum]
# ...               ...                                                ...
# 2185            Dexes                                         [Ethereum]
# 2186      Derivatives                                         [Moonbeam]
# 2187            Dexes                                          [Cardano]
# 2188          Staking                                        [Avalanche]
# 2189  NFT Marketplace                                            [Aptos]
#
#               mcap                  name symbol  \
# 0     8.691799e+08                  Lido    LDO
# 1     5.817959e+08              MakerDAO    MKR
# 2     4.355203e+08                 Curve    CRV
# 3     8.324608e+08               AAVE V2   AAVE
# 4     3.829421e+09                  WBTC   WBTC
# ...            ...                   ...    ...
# 2185  0.000000e+00            X7 Finance    X7R
# 2186  0.000000e+00         Athos Finance    ATH
# 2187           NaN          Genius Yield      -
# 2188           NaN  Freebie Life Finance    FRB
# 2189           NaN              BlueMove      -
#
#                                                  logo  \
# 0                     https://icons.llama.fi/lido.png
# 1                 https://icons.llama.fi/makerdao.jpg
# 2                    https://icons.llama.fi/curve.png
# 3                  https://icons.llama.fi/aave-v2.png
# 4                     https://icons.llama.fi/wbtc.png
# ...                                               ...
# 2185            https://icons.llama.fi/x7-finance.png
# 2186         https://icons.llama.fi/athos-finance.png
# 2187          https://icons.llama.fi/genius-yield.jpg
# 2188  https://icons.llama.fi/freebie-life-finance.png
# 2189              https://icons.llama.fi/bluemove.png
#
#                              url  \
# 0               https://lido.fi/
# 1          https://makerdao.com/
# 2               https://curve.fi
# 3           https://aave.com\r\n
# 4          https://wbtc.network/
# ...                          ...
# 2185          https://x7.finance
# 2186        http://athos.finance
# 2187  https://www.geniusyield.co
# 2188     https://freebielife.me/
# 2189        https://bluemove.net
#
#                                             referralUrl           tvl  \
# 0     https://stake.lido.fi/?ref=0x08a3c2A819E3de7AC...  5.978244e+09
# 1     https://oasis.app/?ref=0x08a3c2A819E3de7ACa384...  5.928592e+09
# 2                                                   NaN  3.622620e+09
# 3                                                   NaN  3.244447e+09
# 4                                                   NaN  3.058199e+09
# ...                                                 ...           ...
# 2185                                                NaN  0.000000e+00
# 2186                                                NaN  0.000000e+00
# 2187                                                NaN  0.000000e+00
# 2188                                                NaN  0.000000e+00
# 2189                                                NaN  0.000000e+00
#
#         tvlPrevDay   tvlPrevWeek  tvlPrevMonth  \
# 0     5.972340e+09  5.947371e+09  6.098338e+09
# 1     5.930606e+09  6.010108e+09  6.367020e+09
# 2     3.628600e+09  3.610008e+09  3.665655e+09
# 3     3.257733e+09  3.244688e+09  3.260577e+09
# 4     3.044986e+09  3.091124e+09  3.395379e+09
# ...            ...           ...           ...
# 2185           NaN           NaN           NaN
# 2186           NaN           NaN           NaN
# 2187           NaN           NaN           NaN
# 2188           NaN           NaN           NaN
# 2189           NaN           NaN           NaN
#
#                                               chainTvls defillamaId  \
# 0     {'Ethereum': {'tvl': 5936156438.462399, 'tvlPr...         182
# 1     {'Ethereum': {'tvl': 5928592248.705086, 'tvlPr...         118
# 2     {'Optimism': {'tvl': 46567061.60172474, 'tvlPr...           3
# 3     {'pool2': {'tvl': 73168842.49302441, 'tvlPrevD...         111
# 4     {'Ethereum': {'tvl': 3058198786.436822, 'tvlPr...           2
# ...                                                 ...         ...
# 2185  {'Ethereum-treasury': {'tvl': 11843.0809801274...        2353
# 2186  {'Moonbeam-staking': {'tvl': 299269.8696428729...        2355
# 2187  {'Cardano': {'tvl': 0, 'tvlPrevDay': None, 'tv...        2381
# 2188  {'Avalanche': {'tvl': 0, 'tvlPrevDay': None, '...        2389
# 2189  {'Aptos': {'tvl': 0, 'tvlPrevDay': None, 'tvlP...        2396
#
#           oracles parentProtocol      listedAt forkedFrom
# 0             NaN            NaN           NaN        NaN
# 1         [Maker]            NaN           NaN        NaN
# 2              []            NaN           NaN        NaN
# 3     [Chainlink]           AAVE           NaN        NaN
# 4              []            NaN           NaN        NaN
# ...           ...            ...           ...        ...
# 2185           []            NaN  1.670854e+09         []
# 2186  [Chainlink]            NaN  1.670856e+09         []
# 2187           []            NaN  1.671796e+09         []
# 2188           []            NaN  1.672075e+09         []
# 2189           []            NaN  1.672334e+09         []
#
# [2190 rows x 18 columns]
