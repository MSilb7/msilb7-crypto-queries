# %%
from subgrounds.subgrounds import Subgrounds
from subgrounds.pagination import ShallowStrategy
import pandas as pd
import requests as r
import sys
sys.path.append('../')
import defillama_utils as dfl
import optimism_pool_tvls as tvls
from datetime import timedelta
import time
import os

# %% [markdown]
# ### Data Sources
# - Messari Subgraphs: [https://thegraph.com/hosted-service/subgraph/messari/curve-finance-ethereum](https://thegraph.com/hosted-service/subgraph/messari/curve-finance-ethereum)

# %%
chain_list = ['arbitrum','aurora','avalanche','ethereum',\
        'fantom','gnosis','harmony','moonbeam','optimism','polygon']
trailing_num_days = 180
start_time = pd.to_datetime("today") - timedelta(days = trailing_num_days-1)
start_time = int( time.mktime(start_time.timetuple()) )

# def get_messari_sg_pool_snapshots(slug, chains, min_ts, max_ts):
get_curve = tvls.get_messari_sg_pool_snapshots('curve-finance',chain_list,start_time)
# Out:
# curve-finance
# arbitrum
# aurora
# avalanche
# ethereum
# fantom
# gnosis
# harmony
# moonbeam
# optimism
# polygon

# %% [markdown]
# ### Export and Show

# %%
if not os.path.exists('csv_outputs'):
    os.makedirs('csv_outputs')
get_curve.to_csv('csv_outputs/curve_snapshot_data.csv')
# display(get_curve)

# %%
check = get_curve[get_curve['pool_name'] == 'Curve.fi Factory Crypto Pool: stMATIC/WMATIC']
display(check.sort_values(by='timestamp',ascending=False))
# Out:
#                                                      id           timestamp  \
# 48592  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28-19394 2023-02-06 20:50:46
# 48590  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28-19393 2023-02-05 23:56:50
# 48588  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28-19392 2023-02-04 23:47:28
# 48586  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28-19391 2023-02-03 23:35:15
# 48584  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28-19390 2023-02-02 22:13:41
# ...                                                 ...                 ...
# 48242  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28-19219 2022-08-15 23:16:00
# 48240  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28-19218 2022-08-14 23:15:57
# 48238  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28-19217 2022-08-13 23:54:15
# 48236  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28-19216 2022-08-12 23:08:36
# 48234  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28-19215 2022-08-11 23:07:27
#
#        totalValueLockedUSD  dailyVolumeUSD  rewardTokenEmissionsUSD  \
# 48592                  0.0    1.921716e+06                      0.0
# 48590                  0.0    1.806986e+06                      0.0
# 48588                  0.0    7.442294e+05                      0.0
# 48586                  0.0    9.405806e+05                      0.0
# 48584                  0.0    7.380133e+06                      0.0
# ...                    ...             ...                      ...
# 48242                  0.0    3.109839e+06                      0.0
# 48240                  0.0    1.043956e+07                      0.0
# 48238                  0.0    2.187074e+07                      0.0
# 48236                  0.0    8.839896e+06                      0.0
# 48234                  0.0    7.209725e+06                      0.0
#
#                                       protocol_id  protocol_name  \
# 48592  0x0000000022d53366457f9d5e68ec105046fc4383  Curve Finance
# 48590  0x0000000022d53366457f9d5e68ec105046fc4383  Curve Finance
# 48588  0x0000000022d53366457f9d5e68ec105046fc4383  Curve Finance
# 48586  0x0000000022d53366457f9d5e68ec105046fc4383  Curve Finance
# 48584  0x0000000022d53366457f9d5e68ec105046fc4383  Curve Finance
# ...                                           ...            ...
# 48242  0x0000000022d53366457f9d5e68ec105046fc4383  Curve Finance
# 48240  0x0000000022d53366457f9d5e68ec105046fc4383  Curve Finance
# 48238  0x0000000022d53366457f9d5e68ec105046fc4383  Curve Finance
# 48236  0x0000000022d53366457f9d5e68ec105046fc4383  Curve Finance
# 48234  0x0000000022d53366457f9d5e68ec105046fc4383  Curve Finance
#
#        protocol_slug protocol_network  \
# 48592  curve-finance            MATIC
# 48590  curve-finance            MATIC
# 48588  curve-finance            MATIC
# 48586  curve-finance            MATIC
# 48584  curve-finance            MATIC
# ...              ...              ...
# 48242  curve-finance            MATIC
# 48240  curve-finance            MATIC
# 48238  curve-finance            MATIC
# 48236  curve-finance            MATIC
# 48234  curve-finance            MATIC
#
#                                           pool_id  \
# 48592  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28
# 48590  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28
# 48588  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28
# 48586  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28
# 48584  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28
# ...                                           ...
# 48242  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28
# 48240  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28
# 48238  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28
# 48236  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28
# 48234  0xfb6fe7802ba9290ef8b00ca16af4bc26eb663a28
#
#                                           pool_name pool_symbol  \
# 48592  Curve.fi Factory Crypto Pool: stMATIC/WMATIC   stMATIC-f
# 48590  Curve.fi Factory Crypto Pool: stMATIC/WMATIC   stMATIC-f
# 48588  Curve.fi Factory Crypto Pool: stMATIC/WMATIC   stMATIC-f
# 48586  Curve.fi Factory Crypto Pool: stMATIC/WMATIC   stMATIC-f
# 48584  Curve.fi Factory Crypto Pool: stMATIC/WMATIC   stMATIC-f
# ...                                             ...         ...
# 48242  Curve.fi Factory Crypto Pool: stMATIC/WMATIC   stMATIC-f
# 48240  Curve.fi Factory Crypto Pool: stMATIC/WMATIC   stMATIC-f
# 48238  Curve.fi Factory Crypto Pool: stMATIC/WMATIC   stMATIC-f
# 48236  Curve.fi Factory Crypto Pool: stMATIC/WMATIC   stMATIC-f
# 48234  Curve.fi Factory Crypto Pool: stMATIC/WMATIC   stMATIC-f
#
#                                      pool_inputTokens_id       date  id_rank
# 48592  [0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, 0... 2023-02-06        2
# 48590  [0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, 0... 2023-02-05        2
# 48588  [0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, 0... 2023-02-04        2
# 48586  [0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, 0... 2023-02-03        2
# 48584  [0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, 0... 2023-02-02        2
# ...                                                  ...        ...      ...
# 48242  [0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, 0... 2022-08-15        2
# 48240  [0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, 0... 2022-08-14        2
# 48238  [0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, 0... 2022-08-13        2
# 48236  [0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, 0... 2022-08-12        2
# 48234  [0x0d500b1d8e8ef31e21c99d1db9a6444d3adf1270, 0... 2022-08-11        2
#
# [180 rows x 15 columns]

# %%
# group by the specified columns
grouped = get_curve.sort_values(by='timestamp', ascending=False)\
                  .groupby(['protocol_network', 'pool_id', 'pool_name', 'pool_symbol'])

# perform the desired aggregations
aggregated = grouped.agg({'totalValueLockedUSD': 'first'
                          , 'dailyVolumeUSD': 'sum'
                          , 'rewardTokenEmissionsUSD':'sum'
                          ,'timestamp':'nunique'
                          })

aggregated = aggregated.rename(columns={'totalValueLockedUSD':'latest_tvl_usd'
                                        ,'dailyVolumeUSD':'avg_daily_volume_usd'
                                        ,'timestamp':'days_of_trading'})

# reset the index
aggregated = aggregated.reset_index()

aggregated = aggregated[aggregated['pool_id'] != 0]

display(aggregated.sort_values(by='days_of_trading',ascending=False))
aggregated.to_csv('csv_outputs/curve_aggregated_data.csv')
# Out:
#     protocol_network                                     pool_id  \
# 77         AVALANCHE  0xd39016475200ab8957e9c772c949ef54bda69111
# 440            MATIC  0x2ffbce9099cbed86984286a54e5932414af4b717
# 57         AVALANCHE  0x7f90122bf0700f9e7e1f688fe926940e8839f353
# 98            FANTOM  0x24699312cb27c26cfc669459d670559e5e44ee60
# 90            FANTOM  0x0fa949783947bf6c1b171db13aeacbb488845b3f
# ..               ...                                         ...
# 138           FANTOM  0xbd7d823eb731435472028fad5c50379b109d0e6d
# 139           FANTOM  0xbe26e1858fafbf2de92fdd717ac098e34d9e526a
# 488            MATIC  0x8aa1d5874e9cd918d66fdbe0d3caa65301995be0
# 62         AVALANCHE  0xa852739519fd46387e2163fc0fb0efaa94aa83c4
# 156           FANTOM  0xfd54def3bdbd8784a92cffc1290717be7288be01
#
#                                          pool_name      pool_symbol  \
# 77    Curve.fi Factory USD Metapool: deBridge-USDC    deUSDС-3CRV-f
# 440        Curve.fi Factory Plain Pool: agEUR-jEUR      agEURjEUR-f
# 57                    Curve.fi avDAI/avUSDC/avUSDT           av3CRV
# 98        Curve.fi Factory USD Metapool: TOR-2pool  TOR-2pool3CRV-f
# 90                       Curve.fi gDAI/gUSDC/gUSDT            g3CRV
# ..                                             ...              ...
# 138  Curve.fi Factory Plain Pool: fDAI/Stable test         DAISTB-f
# 139        Curve.fi Factory Plain Pool: LambdaPool         Lambda-f
# 488   Curve.fi Factory USD Metapool: Liquidity Luk        LUK3CRV-f
# 62    Curve.fi Factory USD Metapool: MoreMoney USD      MONEY3CRV-f
# 156  Curve.fi Factory Plain Pool: fDAI/Stable test         DAISTB-f
#
#      latest_tvl_usd  avg_daily_volume_usd  rewardTokenEmissionsUSD  \
# 77     1.452388e+05          4.252020e+05                      0.0
# 440    1.796376e+07          1.200812e+09                      0.0
# 57     1.183039e+07          4.622727e+07                      0.0
# 98     7.361424e+06          2.356895e+07                      0.0
# 90     5.198863e+06          5.503731e+07                      0.0
# ..              ...                   ...                      ...
# 138    0.000000e+00          0.000000e+00                      0.0
# 139    0.000000e+00          1.002120e-01                      0.0
# 488    4.382417e+02          1.301003e-01                      0.0
# 62     3.619394e+00          2.507826e-05                      0.0
# 156    0.000000e+00          0.000000e+00                      0.0
#
#      days_of_trading
# 77               180
# 440              180
# 57               180
# 98               180
# 90               180
# ..               ...
# 138                1
# 139                1
# 488                1
# 62                 1
# 156                1
#
# [613 rows x 8 columns]
