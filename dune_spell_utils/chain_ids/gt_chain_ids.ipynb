# %%
import requests
import re
import json
import pandas as pd
import sys 
sys.path.append('../')
from dune_exports import *
from api_helpers import *
from pandas_helpers import *
sys.path.pop()

api_url = 'https://chainid.network/chains.json'

# %%
chain_df = api_json_to_df(api_url)

chain_df = chain_df[['name','chain','nativeCurrency','chainId','explorers']]
# chain_df = pd.json_normalize(chain_df['explorers'])
# print( pd.json_normalize(chain_df['nativeCurrency'].apply(json.loads))['symbol'] ) 
chain_df['nativeCurrency'] = get_element_from_json_column(chain_df['nativeCurrency'],'symbol')
chain_df['explorers'] = get_element_from_json_column(chain_df['explorers'],[0])
chain_df['explorers'] = get_element_from_json_column(chain_df['explorers'],'url')
chain_df = chain_df.rename(columns={'explorers':'explorer'})
display(chain_df)

to_dune_sql_format(chain_df, prepend = 'chains', ['chainId']):
# Out:
#                       name  chain nativeCurrency          chainId  \
# 0         Ethereum Mainnet    ETH            ETH                1
# 1          Expanse Network    EXP            EXP                2
# 2                  Ropsten    ETH            ETH                3
# 3                  Rinkeby    ETH            ETH                4
# 4                   Goerli    ETH            ETH                5
# ..                     ...    ...            ...              ...
# 606                   Palm   Palm           PALM      11297108109
# 607          Ntity Mainnet  Ntity            NTT     197710212030
# 608        Haradev Testnet  Ntity           NTTH     197710212031
# 609       Molereum Network    ETH           MOLE    6022140761023
# 610  Godwoken Testnet (V1)    GWT            CKB  868455272153094
#
#                            explorer
# 0              https://etherscan.io
# 1                               NaN
# 2      https://ropsten.etherscan.io
# 3      https://rinkeby.etherscan.io
# 4       https://goerli.etherscan.io
# ..                              ...
# 606        https://explorer.palm.io
# 607     https://blockscout.ntity.io
# 608  https://blockscout.haradev.com
# 609                             NaN
# 610    https://v1.aggron.gwscan.com
#
# [611 rows x 5 columns]
